# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import open3d as o3d
import cv2

import json

current_directory = os.getcwd()

# %% [markdown]
# ## Load ScanNet scene

# %%
scan = "scene0000_00"

scan_path = os.path.join(current_directory, "data/scans", scan)
scene_mesh_path = os.path.join(scan_path, scan + "_vh_clean_2.ply")
scene_mesh = o3d.io.read_triangle_mesh(scene_mesh_path)
segmentation_mesh_path = os.path.join(scan_path, scan + "_vh_clean_2.labels.ply")
segmentation_mesh = o3d.io.read_triangle_mesh(segmentation_mesh_path)

# o3d.visualization.draw_geometries([scene_mesh])

# %% [markdown]
# ## Select a class

# %% [markdown]
# The class must be chosen among one of the raw_category in the [scannetv2-labels.combinesd.tsv](data/scannetv2-labels.combined.tsv)

# %%
with open(os.path.join(scan_path, scan + '_vh_clean.aggregation.json')) as f:
    aggregation_data = json.load(f)

all_classes = set()
for seg_group in aggregation_data['segGroups']:
    all_classes.add(seg_group['label'])

print("All labels in the aggregation data: ", all_classes)
# Out:
# All labels in the aggregation data:  {'kitchen cabinets', 'guitar case', 'doorframe', 'door', 'guitar', 'couch', 'shelf', 'kitchen counter', 'refrigerator', 'wall', 'shoes', 'trash can', 'toaster oven', 'tv', 'curtain', 'laundry basket', 'bicycle', 'pillow', 'coffee table', 'toaster', 'stool', 'toilet', 'table', 'backpack', 'floor', 'clock', 'nightstand', 'mirror', 'cabinet', 'bed', 'scale', 'shower', 'sink', 'object', 'window', 'dish rack', 'tissue box', 'microwave', 'ceiling', 'desk'}

# %%
class_name = 'table'

with open(os.path.join(scan_path, scan + '_vh_clean.aggregation.json')) as f:
    aggregation_data = json.load(f)

object_ids = []
for seg_group in aggregation_data['segGroups']:
    if seg_group['label'] == class_name:
        object_ids.append(seg_group['objectId'])

if not object_ids:
    print("No objects found for class:", class_name)
else:
    print(f"Found {len(object_ids)} objects for class {class_name}: {object_ids}")
# Out:
# Found 3 objects for class table: [3, 4, 5]

# %% [markdown]
# ## Select an object

# %%
object_id = 37

for seg_group in aggregation_data['segGroups']:
    if seg_group['objectId'] == object_id:
        selected_instance_segments = seg_group['segments']

# Load all vertices
with open(os.path.join(scan_path, scan + '_vh_clean_2.0.010000.segs.json')) as f:
    segmentation_data = json.load(f)

# Load instance vertices
all_vertices = np.array(segmentation_data['segIndices'])

# Get indices of instance vertices
instance_vertices_mask = np.isin(all_vertices, selected_instance_segments)
instance_vertex_indices = np.where(instance_vertices_mask)[0]

# Filter faces of the mesh: included if all its vertices are part of the instance
faces = np.asarray(scene_mesh.triangles)
face_mask = np.all(np.isin(faces, instance_vertex_indices), axis=1)
instance_faces = faces[face_mask] # Triplets of vertex indices forming each triangle (the indices refer to scene vertices - all of them)
instance_vertices = np.asarray(scene_mesh.vertices)[instance_vertex_indices] # Coordinates of each vertex
vertex_remap = {scene_idx: instance_idx for instance_idx, scene_idx in enumerate(instance_vertex_indices)}
instance_faces = np.vectorize(vertex_remap.get)(instance_faces) # Triplets of vertex indices forming each triangle (the indices refer to instance vertices - masked)

# Create the mesh for the selected instance
instance_mesh = o3d.geometry.TriangleMesh()
instance_mesh.vertices = o3d.utility.Vector3dVector(instance_vertices)
instance_mesh.triangles = o3d.utility.Vector3iVector(instance_faces)

# o3d.visualization.draw_geometries([instance_mesh])

# %% [markdown]
# ## Get camera parameters

# %% [markdown]
# ### Export camera parameters
# **Note:** This step should be performed only at the beginning of the process.

# %%
reader_directory = os.path.join(current_directory, "scripts/SensReader")
sens_file = os.path.join(scan_path, scan + ".sens")
output_directory = os.path.join(current_directory, "outputs/reader/"+scan)

os.system(f"python {os.path.join(reader_directory, 'reader.py')} --filename {sens_file} --output_path {output_directory} --export_depth_images --export_color_images --export_poses --export_intrinsics --export_depth_images")
# Out:
# Namespace(filename='/Users/lara/Desktop/Making-CLIP-features-multiview-consistent/data/scans/scene0000_00/scene0000_00.sens', output_path='/Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00', export_depth_images=True, export_color_images=True, export_poses=True, export_intrinsics=True)
# loading /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/data/scans/scene0000_00/scene0000_00.sens...loaded!
# exporting 5578  depth frames to /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/depth

# %% [markdown]
# ### Load camera parameters

# %%
output_directory = os.path.join(current_directory, "outputs/reader/"+scan)
pose_directory = os.path.join(output_directory, "pose")
originals_directory = os.path.join(output_directory, "color")
depth_directory = os.path.join(output_directory, "depth")
pose_files = [f for f in os.listdir(pose_directory) if f.endswith('.txt')]
color_files = [f for f in os.listdir(originals_directory) if f.endswith('.jpg')]
frame_indices = [int(f.split('.')[0]) for f in color_files]
intrinsics = np.loadtxt(os.path.join(output_directory, "intrinsic", "intrinsic_color.txt"))  # Camera intrinsics
# extrinsics = np.loadtxt(os.path.join(output_directory, "intrinsic", "extrinsic_color.txt"))  # Camera estrinsic
camera_intrinsics = intrinsics[:3, :3]

# %% [markdown]
# ## Select frames that contain the specific object

# %% [markdown]
# ### Select minimum_vertices in an image
# Select the percentage of the object you want in the frame

# %%
percentage = 80

total_vertices = instance_vertices.shape[0]
minimum_vertices = int(percentage / 100 * total_vertices)

total_faces = instance_faces.shape[0]
minimum_faces = int(percentage / 100 * total_vertices)

print(minimum_vertices)
# Out:
# 2363

# %% [markdown]
# ## Get masked images

# %% [markdown]
# ### Select margin of error for depth

# %%
# Tolerance on occlusions in meters
error = 0.8

# %% [markdown]
# ### Get masked images

# %%
def get_2d_homogeneous(points_3d, intrinsic, extrinsic):
    inv_extrinsic = np.linalg.inv(extrinsic)
    points_3d_homogeneous = np.hstack([points_3d, np.ones((points_3d.shape[0], 1))])
    points_camera = np.dot(inv_extrinsic, points_3d_homogeneous.T).T
    points_camera_xyz = points_camera[:, :3] # Extract only the x, y, z components because the intrinsic matrix is 3x3
    points_2d_homogeneous = np.dot(intrinsic, points_camera_xyz.T).T # the third value is the depth
    return points_2d_homogeneous

def get_original_frame(frame_index):
    original_path = os.path.join(originals_directory, f"{frame_index}.jpg")

    if not os.path.exists(original_path):
        print(f"Error: No file found at {original_path}")
    else:
        # Try to read the image
        image = cv2.imread(original_path)
        if image is None:
            print(f"Error: Failed to read the image from {original_path}")
        else:
            # Convert color from BGR to RGB
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            # You can now use image_rgb for your processing
            print(f"Image from {original_path} loaded and converted successfully.")
            return image_rgb
    return

def get_camera_extrinsics(frame_index):
    extrinsics_path = os.path.join(pose_directory, f"{frame_index}.txt")
    return  np.loadtxt(extrinsics_path)

# Get projected points and z coordinate
def get_xyz(vertices, intrinsics, extrinsics):
    points_2d = get_2d_homogeneous(vertices, intrinsics, extrinsics)
    points_2d_xy = (points_2d[:, :2] / points_2d[:, 2].reshape(-1, 1)).astype(int)
    points_2d[:, :2] = points_2d_xy
    return points_2d

def get_occluded_vertices_idx(depth, points):
    total_vertices = points.shape[0]
    image_width, image_height = depth.shape
    occluded_idx = []
    valid_vertices = 0
    for vertex in range(total_vertices):
        point = points[vertex]
        # Check if the vertex falls into the image
        if (point[0] >= 0)& (point[0] < image_width) & (point[1] >= 0) & (point[1] < image_height):
            # Check if the vertex is in front of the camera
            if point[2] > 0:
                valid_vertices += 1
                # Check if the vertex is occluded
                if depth[int(point[0]), int(point[1])] + error < point[2]:
                    occluded_idx.append(vertex)
    return valid_vertices, occluded_idx

def get_camera_for_rendering(camera_extrinsics, camera_intrinsics, h, w):
    camera = o3d.camera.PinholeCameraParameters()
    intrinsic = o3d.camera.PinholeCameraIntrinsic()
    intrinsic.set_intrinsics(width=w, height=h, fx=camera_intrinsics[0][0], fy=camera_intrinsics[1][1], cx=camera_intrinsics[0][2], cy=camera_intrinsics[1][2])
    camera.intrinsic = intrinsic
    camera.extrinsic = np.array(np.linalg.inv(camera_extrinsics))
    return camera

def render_image(mesh, camera, w, h):
    vis = o3d.visualization.Visualizer()
    vis.create_window(visible=False, width = w, height = h)
    mesh.paint_uniform_color([0, 0, 0])  # Black mesh
    vis.add_geometry(mesh)
    vis.get_view_control().convert_from_pinhole_camera_parameters(camera, True)
    vis.get_render_option().background_color = np.array([1, 1, 1])  # White background
    vis.get_render_option().light_on = False
    vis.poll_events()
    vis.update_renderer()
    image = vis.capture_screen_float_buffer(do_render=False)
    vis.destroy_window()
    return image

def process_frame(frame_index, vis):
    original_frame = get_original_frame(frame_index)
    if original_frame is not None:
        pass
    else:
        return
    image_height, image_width = original_frame.shape[:2]
    camera_extrinsics = get_camera_extrinsics(frame_index)
    points_2d = get_xyz(np.asarray(instance_mesh.vertices), camera_intrinsics, camera_extrinsics)
    camera = get_camera_for_rendering(camera_extrinsics, camera_intrinsics, image_height, image_width)
    vis.get_view_control().convert_from_pinhole_camera_parameters(camera, True)
    depth = np.asarray(vis.capture_depth_float_buffer(do_render=True))

    valid_vertices, vertices_to_remove = get_occluded_vertices_idx(depth, points_2d)
    
    if valid_vertices - len(vertices_to_remove) < minimum_vertices:
        return
    
    vertices_to_remove = set(vertices_to_remove)
    all_faces = np.asarray(instance_mesh.triangles)
    faces_to_keep = [face for face in all_faces if not any(vertex in vertices_to_remove for vertex in face)]

    # Re-index faces: create a mapping from old to new vertex indices
    remaining_vertices_indices = list(set(range(len(instance_mesh.vertices))) - vertices_to_remove)
    new_index_map = {old_idx: new_idx for new_idx, old_idx in enumerate(remaining_vertices_indices)}
    # Update face indices based on new vertex indices
    new_faces = [[new_index_map[vertex] for vertex in face] if all(vertex in new_index_map for vertex in face) else None for face in faces_to_keep]
    new_faces = [face for face in new_faces if face is not None]
    # Get new mesh
    new_vertices = np.asarray(instance_mesh.vertices)[remaining_vertices_indices]
    new_mesh = o3d.geometry.TriangleMesh()
    new_mesh.vertices = o3d.utility.Vector3dVector(new_vertices)
    new_mesh.triangles = o3d.utility.Vector3iVector(new_faces)

    # Rendering
    camera = get_camera_for_rendering(camera_extrinsics, camera_intrinsics, image_height, image_width)
    image = render_image(new_mesh, camera, image_width, image_height)
    image = np.asarray(image)

    # Masking
    mask = (image[:, :, 0] == 0)
    masked_frame_wrong_colors = np.zeros_like(original_frame)
    masked_frame_wrong_colors[mask] = original_frame[mask]
    masked_frame = cv2.cvtColor(masked_frame_wrong_colors, cv2.COLOR_RGB2BGR)

    return masked_frame


masked_images_directory = os.path.join(current_directory, "outputs/masked_images/project_without_occlusion/"+scan, f"{object_id}")
if not os.path.exists(masked_images_directory):
    os.makedirs(masked_images_directory)

original_frame = get_original_frame(0)
image_height, image_width = original_frame.shape[:2]
scene_vis = o3d.visualization.Visualizer()
scene_vis.create_window(visible=False, width = image_width, height = image_height)
scene_vis.add_geometry(scene_mesh)

for frame_index in sorted(frame_indices):
    masked_frame = process_frame(frame_index, scene_vis)
    if masked_frame is not None:
        output_path = os.path.join(masked_images_directory, f"{frame_index:05d}.jpg")
        cv2.imwrite(output_path, masked_frame)
# Out:
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/0.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/0.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/1.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/2.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/3.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/4.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/5.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/6.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/7.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/8.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/9.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/10.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/11.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/12.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/13.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/14.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/15.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/16.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/17.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/18.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/19.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/20.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/21.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/22.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/23.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/24.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/25.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/26.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/27.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/28.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/29.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/30.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/31.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/32.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/33.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/34.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/35.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/36.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/37.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/38.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/39.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/40.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/41.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/42.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/43.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/44.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/45.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/46.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/47.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/48.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/49.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/50.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/51.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/52.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/53.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/54.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/55.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/56.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/57.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/58.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/59.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/60.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/61.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/62.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/63.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/64.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/65.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/66.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/67.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/68.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/69.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/70.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/71.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/72.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/73.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/74.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/75.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/76.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/77.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/78.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/79.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/80.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/81.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/82.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/83.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/84.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/85.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/86.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/87.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/88.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/89.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/90.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/91.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/92.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/93.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/94.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/95.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/96.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/97.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/98.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/99.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/100.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/101.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/102.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/103.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/104.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/105.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/106.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/107.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/108.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/109.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/110.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/111.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/112.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/113.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/114.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/115.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/116.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/117.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/118.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/119.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/120.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/121.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/122.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/123.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/124.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/125.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/126.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/127.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/128.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/129.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/130.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/131.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/132.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/133.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/134.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/135.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/136.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/137.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/138.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/139.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/140.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/141.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/142.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/143.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/144.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/145.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/146.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/147.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/148.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/149.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/150.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/151.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/152.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/153.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/154.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/155.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/156.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/157.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/158.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/159.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/160.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/161.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/162.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/163.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/164.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/165.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/166.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/167.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/168.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/169.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/170.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/171.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/172.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/173.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/174.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/175.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/176.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/177.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/178.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/179.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/180.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/181.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/182.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/183.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/184.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/185.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/186.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/187.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/188.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/189.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/190.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/191.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/192.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/193.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/194.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/195.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/196.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/197.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/198.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/199.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/200.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/201.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/202.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/203.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/204.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/205.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/206.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/207.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/208.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/209.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/210.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/211.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/212.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/213.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/214.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/215.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/216.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/217.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/218.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/219.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/220.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/221.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/222.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/223.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/224.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/225.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/226.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/227.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/228.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/229.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/230.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/231.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/232.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/233.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/234.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/235.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/236.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/237.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/238.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/239.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/240.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/241.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/242.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/243.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/244.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/245.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/246.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/247.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/248.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/249.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/250.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/251.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/252.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/253.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/254.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/255.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/256.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/257.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/258.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/259.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/260.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/261.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/262.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/263.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/264.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/265.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/266.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/267.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/268.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/269.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/270.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/271.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/272.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/273.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/274.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/275.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/276.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/277.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/278.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/279.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/280.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/281.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/282.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/283.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/284.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/285.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/286.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/287.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/288.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/289.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/290.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/291.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/292.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/293.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/294.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/295.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/296.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/297.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/298.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/299.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/300.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/301.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/302.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/303.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/304.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/305.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/306.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/307.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/308.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/309.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/310.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/311.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/312.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/313.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/314.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/315.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/316.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/317.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/318.jpg loaded and converted successfully.
# ...
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/902.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/903.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/904.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/905.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/906.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/907.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/908.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/909.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/910.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/911.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/912.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/913.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/914.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/915.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/916.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/917.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/918.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/919.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/920.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/921.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/922.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/923.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/924.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/925.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/926.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/927.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/928.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/929.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/930.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/931.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/932.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/933.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/934.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/935.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/936.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/937.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/938.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/939.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/940.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/941.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/942.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/943.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/944.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/945.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/946.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/947.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/948.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/949.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/950.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/951.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/952.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/953.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/954.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/955.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/956.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/957.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/958.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/959.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/960.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/961.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/962.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/963.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/964.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/965.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/966.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/967.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/968.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/969.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/970.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/971.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/972.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/973.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/974.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/975.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/976.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/977.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/978.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/979.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/980.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/981.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/982.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/983.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/984.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/985.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/986.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/987.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/988.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/989.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/990.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/991.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/992.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/993.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/994.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/995.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/996.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/997.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/998.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/999.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/1000.jpg loaded and converted successfully.
# Image from /Users/lara/Desktop/Making-CLIP-features-multiview-consistent/outputs/reader/scene0000_00/color/1001.jpg loaded and converted successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 137
#     134 scene_vis.add_geometry(scene_mesh)
#     136 for frame_index in sorted(frame_indices):
# --> 137     masked_frame = process_frame(frame_index, scene_vis)
#     138     if masked_frame is not None:
#     139         output_path = os.path.join(masked_images_directory, f"{frame_index:05d}.jpg")
#
# Cell In[8], line 89, in process_frame(frame_index, vis)
#      87 camera = get_camera_for_rendering(camera_extrinsics, camera_intrinsics, image_height, image_width)
#      88 vis.get_view_control().convert_from_pinhole_camera_parameters(camera, True)
# ---> 89 depth = np.asarray(vis.capture_depth_float_buffer(do_render=True))
#      91 valid_vertices, vertices_to_remove = get_occluded_vertices_idx(depth, points_2d)
#      93 if valid_vertices - len(vertices_to_remove) < minimum_vertices:
#
# KeyboardInterrupt:
